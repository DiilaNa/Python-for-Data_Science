# %% [markdown]
# ### Web Scraping is the process of extracting Data from Websites
#         - Requests Library: Pupular and User-friendly puthon library used for making HTTP requests
#                             Simplifies the process of sending and recieving data over the web.
#
#         -Beautiful Soup : Design for parsing HTML and Xml Docuemtns, when u open a web pagem its full of complicated codes..

# %%
import requests

# %%
url = 'http://api.github.com/events'

response = requests.get(url)
print(response)
print(response.status_code)
print(type(response))
# Out:
# <Response [200]>
# 200
# <class 'requests.models.Response'>

# %%
if response.status_code == 200:
    print("Fetching success")
    print(response.headers)
    print(response.headers['content-Type'])
else:
    print("Fetching Failed: " , response.status_code)
# Out:
# Fetching success
# ...

# %%
print(response.text)
# Out:
# [{"id":"6851700685","type":"PushEvent","actor":{"id":246590320,"login":"deepseekhv-star","display_login":"deepseekhv-star","gravatar_id":"","url":"https://api.github.com/users/deepseekhv-star","avatar_url":"https://avatars.githubusercontent.com/u/246590320?"},"repo":{"id":1105666933,"name":"deepseekhv-star/finance-tracer","url":"https://api.github.com/repos/deepseekhv-star/finance-tracer"},"payload":{"repository_id":1105666933,"push_id":29145624253,"ref":"refs/heads/main","head":"3418179465a5baff2d6cbc46e17606ef1ab9ea39","before":"7e3888b131655eb767d0723a8e43efc2e61d4e25"},"public":true,"created_at":"2025-12-19T03:37:41Z"},{"id":"6851700790","type":"PushEvent","actor":{"id":40721155,"login":"kylegl","display_login":"kylegl","gravatar_id":"","url":"https://api.github.com/users/kylegl","avatar_url":"https://avatars.githubusercontent.com/u/40721155?"},"repo":{"id":904099524,"name":"kylegl/kickstart.nvim","url":"https://api.github.com/repos/kylegl/kickstart.nvim"},"payload":{"repository_
# ...

# %%
print(response.json())
print(type(response.json()))
# Out:
# [{'id': '6851700685', 'type': 'PushEvent', 'actor': {'id': 246590320, 'login': 'deepseekhv-star', 'display_login': 'deepseekhv-star', 'gravatar_id': '', 'url': 'https://api.github.com/users/deepseekhv-star', 'avatar_url': 'https://avatars.githubusercontent.com/u/246590320?'}, 'repo': {'id': 1105666933, 'name': 'deepseekhv-star/finance-tracer', 'url': 'https://api.github.com/repos/deepseekhv-star/finance-tracer'}, 'payload': {'repository_id': 1105666933, 'push_id': 29145624253, 'ref': 'refs/heads/main', 'head': '3418179465a5baff2d6cbc46e17606ef1ab9ea39', 'before': '7e3888b131655eb767d0723a8e43efc2e61d4e25'}, 'public': True, 'created_at': '2025-12-19T03:37:41Z'}, {'id': '6851700790', 'type': 'PushEvent', 'actor': {'id': 40721155, 'login': 'kylegl', 'display_login': 'kylegl', 'gravatar_id': '', 'url': 'https://api.github.com/users/kylegl', 'avatar_url': 'https://avatars.githubusercontent.com/u/40721155?'}, 'repo': {'id': 904099524, 'name': 'kylegl/kickstart.nvim', 'url': 'https://api.gi
# ...

# %%
s = response.json()
s[0]["type"]
# Out:
# 'PushEvent'

# %%
if 'application/json' in response.headers.get('Content-Type',''):
    data = response.json()
    print(data)
# Out:
# [{'id': '6851700685', 'type': 'PushEvent', 'actor': {'id': 246590320, 'login': 'deepseekhv-star', 'display_login': 'deepseekhv-star', 'gravatar_id': '', 'url': 'https://api.github.com/users/deepseekhv-star', 'avatar_url': 'https://avatars.githubusercontent.com/u/246590320?'}, 'repo': {'id': 1105666933, 'name': 'deepseekhv-star/finance-tracer', 'url': 'https://api.github.com/repos/deepseekhv-star/finance-tracer'}, 'payload': {'repository_id': 1105666933, 'push_id': 29145624253, 'ref': 'refs/heads/main', 'head': '3418179465a5baff2d6cbc46e17606ef1ab9ea39', 'before': '7e3888b131655eb767d0723a8e43efc2e61d4e25'}, 'public': True, 'created_at': '2025-12-19T03:37:41Z'}, {'id': '6851700790', 'type': 'PushEvent', 'actor': {'id': 40721155, 'login': 'kylegl', 'display_login': 'kylegl', 'gravatar_id': '', 'url': 'https://api.github.com/users/kylegl', 'avatar_url': 'https://avatars.githubusercontent.com/u/40721155?'}, 'repo': {'id': 904099524, 'name': 'kylegl/kickstart.nvim', 'url': 'https://api.gi
# ...

# %%
import requests

url = "http://api.github.com/events"

response = response = requests.get(url)

if response.status_code == 200:
    print('Fetching Successful')
    print( response.text[:100])
else:
    print("Fetching Failed",response.status_code)
# Out:
# Fetching Successful
# [{"id":"6852531403","type":"PushEvent","actor":{"id":46081500,"login":"purang2","display_login":"pur

# %%
data = {'username':'user','password':'pass'}
response = requests.post("https://httpbin.org/post",data)

if response.status_code == 200:
    print("Data Saved Successfully")
else:
    print("saving failed")
# Out:
# Data Saved Successfully

# %%
import requests
url = 'https://jsonplaceholder.typicode.com/posts'
params = {'userId':1,'id':2}
response = requests.get(url,params=params)
print(response.url)
print(response.text)
# Out:
# https://jsonplaceholder.typicode.com/posts?userId=1&id=2
# [
#   {
#     "userId": 1,
#     "id": 2,
#     "title": "qui est esse",
#     "body": "est rerum tempore vitae\nsequi sint nihil reprehenderit dolor beatae ea dolores neque\nfugiat blanditiis voluptate porro vel nihil molestiae ut reiciendis\nqui aperiam non debitis possimus qui neque nisi nulla"
#   }
# ]

# %%
import requests

url = 'https://httpbin.org/get'

username = 'user'
password = 'pass'

response = requests.get(url, auth=(username, password))

if (response.status_code == 200):
    print('Authentication Successful')

    res_text = response.text
    print(res_text)

else:
    print(f"Authenication Failed. Status Code: {response.status_code}")
# Out:
# Authentication Successful
# {
#   "args": {},
#   "headers": {
#     "Accept": "*/*",
#     "Accept-Encoding": "gzip, deflate",
#     "Authorization": "Basic dXNlcjpwYXNz",
#     "Host": "httpbin.org",
#     "User-Agent": "python-requests/2.32.5",
#     "X-Amzn-Trace-Id": "Root=1-6944e901-51843a0753443c0d44d05e6b"
#   },
#   "origin": "61.245.169.163",
#   "url": "https://httpbin.org/get"
# }

# %% [markdown]
# ## Beautiful Soap

# %%
from bs4 import BeautifulSoup

html_doc = """
<html><head><title>The Dormouse's story</title></head>
<body>
<p class="title"><b>The Dormouse's story</b></p>

<p class="story">Once upon a time there were three little sisters; and their names were
<a href="http://example.com/elsie" class="sister" id="link1">Elsie</a>,
<a href="http://example.com/lacie" class="sister" id="link2">Lacie</a> and
<a href="http://example.com/tillie" class="sister" id="link3">Tillie</a>;
and they lived at the bottom of a well.</p>

<p class="story">...</p>
"""

# %%
soap = BeautifulSoup(html_doc,'html.parser')


print(soap.p)
print(soap.a)
print(soap.title)
print(soap.find('p'))
print(soap.find('a'))
# Out:
# <p class="title"><b>The Dormouse's story</b></p>
# <a class="sister" href="http://example.com/elsie" id="link1">Elsie</a>
# <title>The Dormouse's story</title>
# <p class="title"><b>The Dormouse's story</b></p>
# <a class="sister" href="http://example.com/elsie" id="link1">Elsie</a>

# %%
print(soap.find_all)
# Out:
# <bound method Tag.find_all of
# <html><head><title>The Dormouse's story</title></head>
# <body>
# <p class="title"><b>The Dormouse's story</b></p>
# <p class="story">Once upon a time there were three little sisters; and their names were
# <a class="sister" href="http://example.com/elsie" id="link1">Elsie</a>,
# <a class="sister" href="http://example.com/lacie" id="link2">Lacie</a> and
# <a class="sister" href="http://example.com/tillie" id="link3">Tillie</a>;
# and they lived at the bottom of a well.</p>
# <p class="story">...</p>
# </body></html>>

# %%
print(soap.find_all)
# Out:
# <bound method Tag.find_all of
# <html><head><title>The Dormouse's story</title></head>
# <body>
# <p class="title"><b>The Dormouse's story</b></p>
# <p class="story">Once upon a time there were three little sisters; and their names were
# <a class="sister" href="http://example.com/elsie" id="link1">Elsie</a>,
# <a class="sister" href="http://example.com/lacie" id="link2">Lacie</a> and
# <a class="sister" href="http://example.com/tillie" id="link3">Tillie</a>;
# and they lived at the bottom of a well.</p>
# <p class="story">...</p>
# </body></html>>

# %%
import requests
from bs4 import BeautifulSoup


url = "http://example.com"
response = requests.get(url)

if response.status_code == 200:
    soap = BeautifulSoup(response.text,'html.parser')
    print(soap.h1.text)
else:
    print("Fetching Failed: " , response.status_code)
# Out:
# Example Domain
