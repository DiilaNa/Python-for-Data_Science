# %%
import requests
url = "https://api.open-meteo.com/v1/forecast"

params = {'latitude':6.711086980557219,'longitude':79.9097843531687, "current_weather": True}

response = requests.get(url,params=params)

if response.status_code == 200:
    data = response.json()
    current = data["current_weather"]
    print("Temperature",current['temperature'],"*C")
else:
    print("Failed",response.status_code)
# Out:
# Temperature 28.7 *C

# %% [markdown]
# - vision API

# %% [markdown]
# ### Debugging Fundementals
#  - Runtime Errors
#  - Synatx Erros
#  - Logical Erros
#
# - stack trace / traceback - Errors show in this (terminal)

# %%
# import pdb

# %%
# print("Start")
# x = 5
# pdb.set_trace()

# y = 0 
# y = x / y
# print("Finish")
# Out:
# Start
# > c:\users\liyan\appdata\local\temp\ipykernel_4992\2585558299.py(3)<module>()
